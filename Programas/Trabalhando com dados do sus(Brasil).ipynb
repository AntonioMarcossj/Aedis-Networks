# %%
# -*- coding: UTF-8 -*-

import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches

# %%
#padronizando as tabelas
DF1 = pd.read_csv('https://raw.githubusercontent.com/AntonioMarcossj/Aedis-Networks/Dengue/Dados%20SUS/TabelaB2007.csv',sep=';', parse_dates = True, na_values = 0, encoding='utf8',low_memory=False)
DF2 = pd.read_csv('https://raw.githubusercontent.com/AntonioMarcossj/Aedis-Networks/Dengue/Dados%20SUS/TabelaB2008.csv',sep=';', parse_dates = True, na_values = 0, encoding='utf8',low_memory=False)
DF3 = pd.read_csv('https://raw.githubusercontent.com/AntonioMarcossj/Aedis-Networks/Dengue/Dados%20SUS/TabelaB2009.csv',sep=';', parse_dates = True, na_values = 0, encoding='utf8',low_memory=False)
DF4 = pd.read_csv('https://raw.githubusercontent.com/AntonioMarcossj/Aedis-Networks/Dengue/Dados%20SUS/TabelaB2010.csv',sep=';', parse_dates = True, na_values = 0, encoding='utf8',low_memory=False)
DF5 = pd.read_csv('https://raw.githubusercontent.com/AntonioMarcossj/Aedis-Networks/Dengue/Dados%20SUS/TabelaB2011.csv',sep=';', parse_dates = True, na_values = 0, encoding='utf8',low_memory=False)
DF6 = pd.read_csv('https://raw.githubusercontent.com/AntonioMarcossj/Aedis-Networks/Dengue/Dados%20SUS/TabelaB2012.csv',sep=';', parse_dates = True, na_values = 0, encoding='utf8',low_memory=False)

DFLista = ['N',11,12,13,14,15,16,17,'NE',21,22,23,24,25,26,27,28,29,'SE',31,32,33,34,35,'S',41,42,43,'O',50,51,52,'T']
DFCod = pd.DataFrame(dict(list(zip(['Codigo'],[DFLista]))))

DF1['Codigo'] = DFCod['Codigo']
DF2['Codigo'] = DFCod['Codigo']
DF3['Codigo'] = DFCod['Codigo']
DF4['Codigo'] = DFCod['Codigo']
DF5['Codigo'] = DFCod['Codigo']
DF6['Codigo'] = DFCod['Codigo']

DF1 = DF1[[ 'Codigo','Região/UF de notificação', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']]
DF2 = DF2[[ 'Codigo','Região/UF de notificação', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']]
DF3 = DF3[[ 'Codigo','Região/UF de notificação', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']]
DF4 = DF4[[ 'Codigo','Região/UF de notificação', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']]
DF5 = DF5[[ 'Codigo','Região/UF de notificação', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']]
DF6 = DF6[[ 'Codigo','Região/UF de notificação', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']]


DF1.columns = [ 'Codigo','Estado', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']
DF2.columns = [ 'Codigo','Estado', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']
DF3.columns = [ 'Codigo','Estado', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']
DF4.columns = [ 'Codigo','Estado', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']
DF5.columns = [ 'Codigo','Estado', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']
DF6.columns = [ 'Codigo','Estado', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'Total']



DF1.to_csv('TabelaBr2007.csv',index=False)
DF2.to_csv('TabelaBr2008.csv',index=False)
DF3.to_csv('TabelaBr2009.csv',index=False)
DF4.to_csv('TabelaBr2010.csv',index=False)
DF5.to_csv('TabelaBr2011.csv',index=False)
DF6.to_csv('TabelaBr2012.csv',index=False)

# %%
DF1 = pd.read_csv('TabelaBr2007.csv',sep=',', parse_dates = True, encoding='utf8',low_memory=False)
DF2 = pd.read_csv('TabelaBr2008.csv',sep=',', parse_dates = True, encoding='utf8',low_memory=False)
DF3 = pd.read_csv('TabelaBr2009.csv',sep=',', parse_dates = True, encoding='utf8',low_memory=False)
DF4 = pd.read_csv('TabelaBr2010.csv',sep=',', parse_dates = True, encoding='utf8',low_memory=False)
DF5 = pd.read_csv('TabelaBr2011.csv',sep=',', parse_dates = True, encoding='utf8',low_memory=False)
DF6 = pd.read_csv('TabelaBr2012.csv',sep=',', parse_dates = True, encoding='utf8',low_memory=False)

# %%
DF2
# Out:
# pandas.core.frame.DataFrame

# %%
#criando uma lista que contenha o total de todos os anos por meses

DF1Plt =pd.DataFrame(DF1.loc[32,'Jan': 'Dez'])
DF2Plt =pd.DataFrame(DF2.loc[32,'Jan': 'Dez'])
DF3Plt =pd.DataFrame(DF3.loc[32,'Jan': 'Dez'])
DF4Plt =pd.DataFrame(DF4.loc[32,'Jan': 'Dez'])
DF5Plt =pd.DataFrame(DF5.loc[32,'Jan': 'Dez'])
DF6Plt =pd.DataFrame(DF6.loc[32,'Jan': 'Dez'])

#juntei todos em um data frame só
DFPlt = pd.DataFrame({})
DFPlt['casos de 2007']=DF1Plt[32]
DFPlt['casos de 2008']=DF2Plt[32]
DFPlt['casos de 2009']=DF3Plt[32]
DFPlt['casos de 2010']=DF4Plt[32]
DFPlt['casos de 2011']=DF5Plt[32]
DFPlt['casos de 2012']=DF6Plt[32]

#RESOLVENDO O PROBLEMA DO DTYPE= OBJ

pd.to_numeric(DFPlt['casos de 2007'], errors='coerce')
DFPlt['casos de 2007']=DFPlt['casos de 2007'].astype(float)

pd.to_numeric(DFPlt['casos de 2008'], errors='coerce')
DFPlt['casos de 2008']=DFPlt['casos de 2008'].astype(float)

pd.to_numeric(DFPlt['casos de 2009'], errors='coerce')
DFPlt['casos de 2009']=DFPlt['casos de 2009'].astype(float)

pd.to_numeric(DFPlt['casos de 2010'], errors='coerce')
DFPlt['casos de 2010']=DFPlt['casos de 2010'].astype(float)

pd.to_numeric(DFPlt['casos de 2011'], errors='coerce')
DFPlt['casos de 2011']=DFPlt['casos de 2011'].astype(float)

pd.to_numeric(DFPlt['casos de 2012'], errors='coerce')
DFPlt['casos de 2012']=DFPlt['casos de 2012'].astype(float)
#tirei o nome dos meses do index e coloquei números de 1 a 12 para facilitar 
#DFPlt.index=range(1,13)

a07=plt.plot(DF1Plt,color='red',marker='')
a08=plt.plot(DF2Plt,color='darkblue',marker='')
a09=plt.plot(DF3Plt,color='green',marker='')
a10=plt.plot(DF4Plt,color='purple',marker='')
a11=plt.plot(DF5Plt,color='gray',marker='')
a12=plt.plot(DF6Plt,color='pink',marker='')



plt.title('Casos Epidêmicos de Dengue no Brasil entre 2007 e 2012')
plt.ylabel('Número de Casos')
plt.xlabel('Mês')


red_patch = mpatches.Patch(color='red', label='2007')
darkblue_patch= mpatches.Patch(color='darkblue', label='2008')
green_patch=mpatches.Patch(color='green', label='2009')
purple_patch=mpatches.Patch(color='purple', label='2010')
gray_patch=mpatches.Patch(color='gray', label='2011')
pink_patch=mpatches.Patch(color='pink', label='2012')

plt.legend(handles=[red_patch,darkblue_patch,green_patch,purple_patch,gray_patch,pink_patch])
plt.show()



#Plot de 2007 - 2012 "Pie"
Meses= ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun',
       'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']

#DF1Plt = DF1.loc[32,'Jan': 'Dez']

#DFPlt.plot(kind='line',colormap='tab20c',fontsize = 10, legend= True,figsize= (10,10),subplots=True)
#plt.ylabel('Casos Epidêmicos de Dengue em 2007 no Brasil')
#plt.legend(loc='best')


#DF2Plt.plot(kind='Pie',colormap='tab20c',table=True,fontsize = 10, legend= True,figsize= (10,10)  )
#plt.ylabel('Casos Epidêmicos de Dengue em 2008 no Brasil')
#plt.legend(loc='best')


#DF3Plt.plot(kind='pie',colormap='tab20c',table=True,fontsize = 10, legend= True,figsize= (10,10)  )
#plt.ylabel('Casos Epidêmicos de Dengue em 2007 no Brasil')
#plt.legend(loc='best')


#DF4Plt.plot(kind='pie',colormap='tab20c',table=True,fontsize = 10, legend= True,figsize= (10,10)  )
#plt.ylabel('Casos Epidêmicos de Dengue em 2007 no Brasil')
#plt.legend(loc='best')


#DF5Plt.plot(kind='pie',colormap='tab20c',table=True,fontsize = 10, legend= True,figsize= (10,10)  )
#plt.ylabel('Casos Epidêmicos de Dengue em 2007 no Brasil')
#plt.legend(loc='best')


#DF6Plt.plot(kind='pie',colormap='tab20c',table=True,fontsize = 10, legend= True,figsize= (10,10)  )
#plt.ylabel('Casos Epidêmicos de Dengue em 2007 no Brasil')
#plt.legend(loc='best')


plt.show()

# %%
DFPlt['casos de 2007'].plot.pie(subplots =True,figsize=(10,10),colormap='tab20')
plt.title('Casos Epidêmicos de Dengue em 2007 no Brasil')
plt.legend(loc='best')
plt.savefig('Casos Epidêmicos de Dengue em 2007 no Brasil.png')
plt.show()

DFPlt['casos de 2008'].plot.pie(subplots =True,figsize=(10,10),colormap='tab20')
plt.ylabel('Casos Epidêmicos de Dengue em 2008 no Brasil')
plt.legend(loc='best')
plt.savefig('Casos Epidêmicos de Dengue em 2008 no Brasil.png')
plt.show()

DFPlt['casos de 2009'].plot.pie(subplots =True,figsize=(10,10),colormap='tab20')
plt.title('Casos Epidêmicos de Dengue em 2009 no Brasil')
plt.legend(loc='best')
plt.savefig('Casos Epidêmicos de Dengue em 2009 no Brasil.png')
plt.show()

DFPlt['casos de 2010'].plot.pie(subplots =True,figsize=(10,10),colormap='tab20')
plt.title('Casos Epidêmicos de Dengue em 2010 no Brasil')
plt.legend(loc='best')
plt.savefig('Casos Epidêmicos de Dengue em 2010 no Brasil.png')
plt.show()

DFPlt['casos de 2011'].plot.pie(subplots =True,figsize=(10,10),colormap='tab20')
plt.title('Casos Epidêmicos de Dengue em 2011 no Brasil')
plt.legend(loc='best')
plt.savefig('Casos Epidêmicos de Dengue em 2011 no Brasil.png')
plt.show()

DFPlt['casos de 2012'].plot.pie(subplots =True,figsize=(10,10),colormap='tab20')
plt.title('Casos Epidêmicos de Dengue em 2012 no Brasil')
plt.legend(loc='best')
plt.savefig('Casos Epidêmicos de Dengue em 2012 no Brasil.png')
plt.show()

# %%
plt
